# %% [markdown]
# # **Dynamics and Control with Jupyter Notebook**
#
# - Tutorial Link: https://dynamics-and-control.readthedocs.io/en/latest/2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.html
#
# misc:
# - Main Link: https://dynamics-and-control.readthedocs.io/en/latest/index.html
# - Github Link: https://github.com/alchemyst/Dynamics-and-Control
# - Youtube Link: https://www.youtube.com/@processdynamicsandcontrol3819/playlists

# %%
import control
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
s = control.tf([1, 0], 1)
ts = numpy.linspace(0, 5)

# %%
def plot_step_response(G):
    t, y = control.step_response(G, ts)
    # Add some action before time zero so that the initial step is visible
    t = numpy.concatenate([[-1, 0], t])
    y = numpy.concatenate([[0, 0], y])
    plt.plot(t, y)

# %% [markdown]
# ## PI

# %%
K_C = 1
tau_I = 1
Gc = K_C*(1 + 1/(tau_I*s))
plot_step_response(Gc)

# %% [markdown]
# ## PID

# %%
alpha = 0.1
tau_D = 1
Gc = K_C*(1 + 1/(tau_I*s) + 1*s/(alpha*tau_D*s + 1))
plot_step_response(Gc)

# %%
Gc = K_C*(1 + 1*s/(alpha*tau_D*s + 1))
plot_step_response(Gc)
